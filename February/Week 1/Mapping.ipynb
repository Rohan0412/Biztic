# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import re

import warnings
warnings.filterwarnings('ignore')

from flask import Flask
from flask import request
from flask import render_template
import mysql.connector
from mysql.connector import Error
import string

# %%
# Connect to MYSQL Database
connection = mysql.connector.connect(host='winv-ahd-003',
            database='vonly_data_feed_us_staging',
            user='vonly-agent',
            password='a714fded-311c-4215-8b8b-5df4086e264b')

# %%
# # # 444bd446-fff0-479a-b535-859c9a75a796
# # # 40f43d4d-206a-4430-8232-a7ea89b7fca0
# # # First SQL Query
# for id_1 in v_id:
#     query1 = """
#         SELECT ti.platform,ti.title ,ti.vonly_asset_id source_vonly,ti.num,ti.portal_item_id ,
#     t.director,t.actors,t.name,t.writers,t.produced_by,t.distributed_by_parent,t.producers,t.runtime 
#     FROM tv_ids ti
#     LEFT OUTER JOIN sandbox.tvshows t ON ti.id = t.vonly_id AND ti.region = t.region
#     WHERE ti.vonly_asset_id = '{}'; """.format(id_1)  

#     df1 = pd.read_sql_query(query1, connection)

#     # Second SQL Query
#     query2 = """
#         SELECT tis.platform,tis.title des_title,tis.vonly_asset_id source_vonly,tis.num des_num_season,tis.portal_item_id source_portal_id, 
#     tie.platform,tie.title,tie.vonly_asset_id des_vonly,tie.num des_num_epi,tie.portal_item_id des_portal_id,t.director,t.actors,
#     t.name,t.writers,t.produced_by,t.distributed_by_parent,t.producers,t.runtime
#     FROM tv_id_mappings tim
#     LEFT OUTER JOIN tv_ids tis ON tim.season_vonly_id=tis.id 
#     LEFT OUTER JOIN tv_ids tie ON tim.episode_vonly_id=tie.id
#     LEFT OUTER JOIN sandbox.tvshows t ON tis.id=t.vonly_id AND tis.region=t.region
#     WHERE tis.vonly_asset_id IN ('{}')
#     ORDER BY 4,8;""".format(id_1) 

#     df2 = pd.read_sql_query(query2, connection)

#     # Close the database connection
#     connection.close()

# %%
# Assuming you have a list of vonly_asset_id values
# vonly_asset_ids = ['444bd446-fff0-479a-b535-859c9a75a796', '40f43d4d-206a-4430-8232-a7ea89b7fca0']


# # Create an empty DataFrame to store the results
# result_df = pd.DataFrame()

# # Loop through each vonly_asset_id
# for vonly_asset_id in vonly_asset_ids:
#     # First SQL Query
#     query1 = f"""
#         SELECT ti.platform,ti.title ,ti.vonly_asset_id source_vonly,ti.num,ti.portal_item_id ,
#         t.director,t.actors,t.name,t.writers,t.produced_by,t.distributed_by_parent,t.producers,t.runtime 
#         FROM tv_ids ti
#         LEFT OUTER JOIN sandbox.tvshows t ON ti.id = t.vonly_id AND ti.region = t.region
#         WHERE ti.vonly_asset_id = '{vonly_asset_id}';
#     """

#     df1 = pd.read_sql_query(query1, connection)
#     result_df = pd.concat([result_df, df1], ignore_index=True)

#     # Second SQL Query
#     query2 = f"""
#         SELECT tis.platform,tis.title des_title,tis.vonly_asset_id source_vonly,tis.num des_num_season,tis.portal_item_id source_portal_id, 
#         tie.platform,tie.title,tie.vonly_asset_id des_vonly,tie.num des_num_epi,tie.portal_item_id des_portal_id,t.director,t.actors,
#         t.name,t.writers,t.produced_by,t.distributed_by_parent,t.producers,t.runtime
#         FROM tv_id_mappings tim
#         LEFT OUTER JOIN tv_ids tis ON tim.season_vonly_id=tis.id 
#         LEFT OUTER JOIN tv_ids tie ON tim.episode_vonly_id=tie.id
#         LEFT OUTER JOIN sandbox.tvshows t ON tis.id=t.vonly_id AND tis.region=t.region
#         WHERE tis.vonly_asset_id IN ('{vonly_asset_id}')
#         ORDER BY 4,8;
#     """

#     df2 = pd.read_sql_query(query2, connection)
#     result_df = pd.concat([result_df, df2], ignore_index=True)

# # Close the database connection
# connection.close()

# # Display the final result DataFrame
# result_df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[46], line 19
#       9 for vonly_asset_id in vonly_asset_ids:
#      10     # First SQL Query
#      11     query1 = f"""
#      12         SELECT ti.platform,ti.title ,ti.vonly_asset_id source_vonly,ti.num,ti.portal_item_id ,
#      13         t.director,t.actors,t.name,t.writers,t.produced_by,t.distributed_by_parent,t.producers,t.runtime
#    (...)
#      16         WHERE ti.vonly_asset_id = '{vonly_asset_id}';
#      17     """
# ---> 19     df1 = pd.read_sql_query(query1, connection)
#      20     result_df = pd.concat([result_df, df1], ignore_index=True)
#      22     # Second SQL Query
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:469, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     466     dtype_backend = "numpy"  # type: ignore[assignment]
#     468 with pandasSQL_builder(con) as pandas_sql:
# --> 469     return pandas_sql.read_query(
#     470         sql,
#     471         index_col=index_col,
#     472         params=params,
#     473         coerce_float=coerce_float,
#     474         parse_dates=parse_dates,
#     475         chunksize=chunksize,
#     476         dtype=dtype,
#     477         dtype_backend=dtype_backend,
#     478     )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:2266, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2255 def read_query(
#    2256     self,
#    2257     sql,
#    (...)
#    2264     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2265 ) -> DataFrame | Iterator[DataFrame]:
# -> 2266     cursor = self.execute(sql, params)
#    2267     columns = [col_desc[0] for col_desc in cursor.description]
#    2269     if chunksize is not None:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:2200, in SQLiteDatabase.execute(self, sql, params)
#    2198     raise TypeError("Query must be a string unless using sqlalchemy.")
#    2199 args = [] if params is None else [params]
# -> 2200 cur = self.con.cursor()
#    2201 try:
#    2202     cur.execute(sql, *args)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\connection.py:1215, in MySQLConnection.cursor(self, buffered, raw, prepared, cursor_class, dictionary, named_tuple)
#    1212 self.handle_unread_result()
#    1214 if not self.is_connected():
# -> 1215     raise OperationalError("MySQL Connection not available")
#    1216 if cursor_class is not None:
#    1217     if not issubclass(cursor_class, CursorBase):
#
# OperationalError: MySQL Connection not available

# %%
# for id_1 in v_id:
#     print("\n","Test Case: ",test_case)
#     #print(id_1)
#     test_case=test_case+1
# 444bd446-fff0-479a-b535-859c9a75a796
# 40f43d4d-206a-4430-8232-a7ea89b7fca0
# First SQL Query
query1 = """
    SELECT ti.platform,ti.title ,ti.vonly_asset_id source_vonly,ti.num,ti.portal_item_id ,
t.director,t.actors,t.name,t.writers,t.produced_by,t.distributed_by_parent,t.producers,t.runtime 
FROM tv_ids ti
LEFT OUTER JOIN sandbox.tvshows t ON ti.id = t.vonly_id AND ti.region = t.region
WHERE ti.vonly_asset_id = '444bd446-fff0-479a-b535-859c9a75a796';
 
"""

df1 = pd.read_sql_query(query1, connection)

# Second SQL Query
query2 = """
    SELECT tis.platform,tis.title des_title,tis.vonly_asset_id source_vonly,tis.num des_num_season,tis.portal_item_id source_portal_id, 
tie.platform,tie.title,tie.vonly_asset_id des_vonly,tie.num des_num_epi,tie.portal_item_id des_portal_id,t.director,t.actors,
t.name,t.writers,t.produced_by,t.distributed_by_parent,t.producers,t.runtime
FROM tv_id_mappings tim
LEFT OUTER JOIN tv_ids tis ON tim.season_vonly_id=tis.id 
LEFT OUTER JOIN tv_ids tie ON tim.episode_vonly_id=tie.id
LEFT OUTER JOIN sandbox.tvshows t ON tis.id=t.vonly_id AND tis.region=t.region
WHERE tis.vonly_asset_id IN ('444bd446-fff0-479a-b535-859c9a75a796')
ORDER BY 4,8;
"""

df2 = pd.read_sql_query(query2, connection)

# Close the database connection
connection.close()

# %%
df1.columns
# Out:
# Index(['platform', 'title', 'source_vonly', 'num', 'portal_item_id',
#        'director', 'actors', 'name', 'writers', 'produced_by',
#        'distributed_by_parent', 'producers', 'runtime'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['platform', 'des_title', 'source_vonly', 'des_num_season',
#        'source_portal_id', 'platform', 'title', 'des_vonly', 'des_num_epi',
#        'des_portal_id', 'director', 'actors', 'name', 'writers', 'produced_by',
#        'distributed_by_parent', 'producers', 'runtime'],
#       dtype='object')

# %%
df1.head(3)
# Out:
#      platform                               title  \
# 0  AppleTVApp  Band of Brothers, Pt. 8:The Patrol
# 1  AppleTVApp  Band of Brothers, Pt. 8:The Patrol
# 2  AppleTVApp  Band of Brothers, Pt. 8:The Patrol
#
#                            source_vonly num  \
# 0  444bd446-fff0-479a-b535-859c9a75a796   8
# 1  444bd446-fff0-479a-b535-859c9a75a796   8
# 2  444bd446-fff0-479a-b535-859c9a75a796   8
#
#                              portal_item_id director actors  name writers  \
# 0         umc.cmc.53h8cr322s00q9hotpyx767rf     None   None  None    None
# 1  umc.cmr.its.ep.56dstj5gnd9wuw0w276kry2z8     None   None  None    None
# 2                    tvs.sbd.9001:583011377     None   None  None    None
#
#   produced_by distributed_by_parent producers runtime
# 0        None                  None      None    None
# 1        None                  None      None    None
# 2        None                  None      None    None

# %%
df2.head(3)
# Out:
#   platform                         des_title  \
# 0   iTunes  Band of Brothers and The Pacific
# 1   iTunes  Band of Brothers and The Pacific
# 2   iTunes  Band of Brothers and The Pacific
#
#                            source_vonly des_num_season source_portal_id  \
# 0  444bd446-fff0-479a-b535-859c9a75a796              1        582727129
# 1  444bd446-fff0-479a-b535-859c9a75a796              1        582727129
# 2  444bd446-fff0-479a-b535-859c9a75a796              1        582727129
#
#   platform                                        title  \
# 0   iTunes  Band of Brothers, Pt. 7: The Breaking Point
# 1   iTunes                           The Pacific, Pt. 1
# 2   iTunes        Band of Brothers, Pt. 9: Why We Fight
#
#                               des_vonly des_num_epi des_portal_id director  \
# 0  00bf0504-d3d3-4fd8-98c2-eccb3c9cde71           7     583010507     None
# 1  06420e4a-2461-4d21-97d9-05a2f1e80273          12     583018532     None
# 2  06c63afe-b1c3-47fe-9b8f-540847250211           9     583343266     None
#
#   actors  name writers produced_by distributed_by_parent producers runtime
# 0   None  None    None        None                  None      None    None
# 1   None  None    None        None                  None      None    None
# 2   None  None    None        None                  None      None    None

# %%
mapping_list = []
id_ = 0

for _, row1 in df1.iterrows():
    id_ = id_ + 1
    
    count = 0
    mapped = 0
    unmapped = 0
    
    matching_points = {
        'id': id_,
        'title': 0,
        'director': 0,
        'producers': 0,
        'portal_item_id': 0,
        'writers': 0,
        'runtime': 0,
        'count': count,
        'mapped': mapped,
        'unmapped': unmapped
    }

    for _, row2 in df2.iterrows():
        if not pd.isnull(row1['title']) and not pd.isnull(row2['title']) and row1['title'] == row2['title']:
            matching_points['title'] = 1

        if not pd.isnull(row1['director']) and not pd.isnull(row2['director']) and row1['director'] == row2['director']:
            matching_points['director'] = 1

        if not pd.isnull(row1['producers']) and not pd.isnull(row2['producers']) and row1['producers'] == row2['producers']:
            matching_points['producers'] = 1
            
        if not pd.isnull(row1['portal_item_id']) and not pd.isnull(row2['des_portal_id']) and row1['portal_item_id'] == row2['des_portal_id']:
            matching_points['portal_item_id'] = 1

        if not pd.isnull(row1['writers']) and not pd.isnull(row2['writers']) and row1['writers'] == row2['writers']:
            matching_points['writers'] = 1
            
        if not pd.isnull(row1['runtime']) and not pd.isnull(row2['runtime']) and row1['runtime'] == row2['runtime']:
            matching_points['runtime'] = 1
        
        count = matching_points['title'] + matching_points['director'] + matching_points['producers'] + matching_points['portal_item_id'] + matching_points['writers'] + matching_points['runtime']
        
        if count >= 3:
            mapped = 1
        else:
            unmapped = 1

    matching_points['count'] = count
    matching_points['mapped'] = mapped
    matching_points['unmapped'] = unmapped
    
    mapping_list.append(matching_points)

mapping_list
# Out:
# [{'id': 1,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 0,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 2,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 3,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 4,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 5,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 6,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 7,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 8,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 9,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 10,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 11,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 12,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 13,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 14,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 15,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 16,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 17,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 18,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 19,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 20,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 21,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 22,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 23,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 24,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 25,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 26,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 27,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 28,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 29,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 30,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 31,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 32,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 33,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 34,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 35,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 36,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 37,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 38,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 39,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 40,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 41,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 42,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 43,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 44,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 45,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 46,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 47,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 48,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 49,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 50,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 51,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 52,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 53,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 54,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 55,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 56,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 57,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 58,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 59,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 60,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 61,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 62,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 63,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 64,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 65,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 66,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 67,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 68,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 69,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 70,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 71,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 72,
#   'title': 1,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1},
#  {'id': 73,
#   'title': 0,
#   'director': 0,
#   'producers': 0,
#   'portal_item_id': 0,
#   'writers': 0,
#   'runtime': 0,
#   'count': 1,
#   'mapped': 0,
#   'unmapped': 1}]
