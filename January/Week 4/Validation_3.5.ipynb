# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import re

import warnings
warnings.filterwarnings('ignore')

from flask import Flask
from flask import request
from flask import render_template
import mysql.connector
from mysql.connector import Error
import string

# %%
# Function to tokenize the episode names
# def token(s): 
#     getVals = list([val for val in s
#                 if val.isalpha() or val.isnumeric()])

#     result = "".join(getVals)
#     result = result.lower()
#     return result



def token(text):
    # Remove everything except normal alphabets and numbers
    cleaned_text = re.sub(r'[^a-zA-Z0-9]', ' ', text)
    
    # Tokenize the cleaned text
    tokens = cleaned_text.split()
    result =""
    for a in tokens:
        result = result + a
    result = result.lower()
    return result

# %%
s="farewellôçª"
token(s)
# Out:
# 'farewell'

# %%
# Test Data

#v_id = ['52c87a97-0663-4188-83b0-8d1db0eae6ec']
v_id = ['96932f06-f7e1-4aa7-b84d-b96e5b32e999',
# '5008fdb1-0c66-46e7-8ecf-cbe03021f950',
#'0707deae-17b9-4ec1-b45d-56532f320f86',
'946fbd54-d3fd-4e66-b5a1-fac18d6305ed',
'52c87a97-0663-4188-83b0-8d1db0eae6ec',
'92e510f1-9ce2-478b-a93d-8e40fd0ca529',
'f9e1fe71-c91a-4ddb-9371-937e40e18ec9',
'720b5551-e62b-4e08-80f7-2067e7151673',
'097c473f-3598-48eb-b303-d822c3fe0206',
'e016138e-bb89-4179-82c1-d60e4e647b72',
'2b6e5d08-758d-4837-abda-b46ba6644bcd',
'c6236338-f69c-44fa-9d41-7c273bea5ab7',
'7c3cc2de-3ff6-48a2-b508-bd9b00f4a61f',
'2f9f6b2c-7bb1-48fa-baaf-cfea2ab20602',
'ffcb664c-9c70-4e1a-bda7-e8d98382178d',
'5a6923c7-fffd-4862-b7f8-949bcd504a50',
'd8aeab3c-56a9-461a-9fea-82d02a35a1fd',
'dd8d7f63-54d2-4968-b5b7-40d8ffe75531',
'c0da4f8d-483b-463a-92ef-7ed97f382221',
'932b94fd-7769-4ebd-8e5c-273e70961c8c',
'850c08ec-28f2-4feb-bb82-f87ba5b3dfdd',
'2ec1fe84-92d9-4080-92e4-b52dda7c518b',
'cd13c993-7b0a-4113-8cb3-c3bf48f91fc0',
#'a7beff11-d9e5-42e4-af88-8f96a30fdec8',
'ee617385-353d-42d8-83ed-44097c368512']

# %%
# Connect to MYSQL Database
connection = mysql.connector.connect(host='winv-ahd-003',
            database='vonly_data_feed_us_staging',
            user='vonly-agent',
            password='a714fded-311c-4215-8b8b-5df4086e264b')

# %%
test_case=3
for id_1 in v_id:
    print("\n","Test Case: ",test_case)
    #print(id_1)
    test_case=test_case+1
    
    # SQL Query
    sql_select_Query = """  
    SELECT  te.platform,te.portal,te.vonly_asset_id ,ts.title 'season_name', ts.num 'season_no',ts.portal_item_id 'season_portal_item_id', 
    te.title 'episode_name',te.num 'episode_no' ,te.portal_item_id  'episode_portal_item_id' 
    FROM tv_id_mappings tim
    INNER JOIN tv_ids te ON te.id=tim.episode_vonly_id
    INNER JOIN tv_ids ts ON ts.id=tim.season_vonly_id
    WHERE tim.season_vonly_id IN (
    SELECT id FROM tv_ids WHERE scope='tv_season' AND vonly_asset_id='{}');""".format(id_1)   

    cursor = connection.cursor()        
    cursor.execute(sql_select_Query)
    records = cursor.fetchall()
#     for r in records:
#         print(r[0], r[7], r[6])
    
    # Dictionaries for each portal and one general to compare where for each keys is episode number and value is apisode name
    amazon = dict()
    vudu = dict()
    google = dict()
    apple = dict()
    itunes = dict()
    general = dict()
    
    
    # Code to fill the above dictionaries, skipping the trailers
    for r in records:
        platform = r[0]
        episode_no = r[7]
        episode_name = r[6]
        if(platform == 'iTunes' ):
            if(int(episode_no)>50 or int(episode_no)==0): 
                continue   
            itunes[episode_no] = episode_name
            
        elif(platform == 'VUDU' ):
            if(int(episode_no)>50 or int(episode_no)==0): 
                continue
            vudu[episode_no] = episode_name
            
        elif(platform == 'Amazon Prime Video' ):
            if(int(episode_no)>50 or int(episode_no)==0): 
                continue
            amazon[episode_no] = episode_name

        elif(platform == 'AppleTVApp' ):
            if(int(episode_no)>50 or int(episode_no)==0): 
                continue
            apple[episode_no] = episode_name
            
        elif(platform == 'Google Play' ):
            if(int(episode_no)>50 or int(episode_no)==0): 
                continue
            google[episode_no] = episode_name
            
        else:
            print("Portal not in the list")
    
    
    # Checking if any portal is not present totally
    amazon_class=itunes_class=appletv_class=vudu_class=google_class=0
    if(len(amazon) == 0 ):
        amazon_class=1
        print("Amazon portal is not there.")

    if(len(itunes) == 0):
        itunes_class=1
        print("iTunes portal is not there.")

    if(len(apple) == 0):
        appletv_class=1
        print("Apple portal is not there.")

    if(len(vudu) == 0):
        vudu_class=1
        print("Vudu portal is not there.")

    if(len(google) == 0):
        google_class=1
        print("Google portal is not there.")

    
    # Check whether each portal have same number of episodes or not
    x=0
    len_= max(len(itunes),len(apple),len(google),len(amazon),len(vudu))
    print("len=",len_)
    if(itunes_class==0):
        if(len(itunes) == len_):
            x=x+1
        else:
            print("iTunes length is not same")

    if(appletv_class==0):
        if(len(apple) == len_):
            x=x+1
        else:
            print("Apple length is not same")
    
    if(amazon_class==0):
        if(len(amazon) == len_):
            x=x+1
        else:
            print("Amazon length is not same")

    if(google_class==0):    
        if(len(google) == len_):
            x=x+1
        else:
            print("Google length is not same")
    
    if(vudu_class==0):
        if(len(vudu) == len_):
            x=x+1
        else:
            print("Vudu length is not same")
        


    #print(x) 
    if(x!=5-(amazon_class+itunes_class+appletv_class+vudu_class+google_class)):
        print("\033[1mNot Properly Mapped Due to Size\033[0m")
        continue
    
#     print(len(itunes))
#     print(len(apple))
#     print(len(amazon))
#     print(len(vudu))
#     print(len(google))
        
         
#     print("a",amazon,"\n")
#     print("i",itunes,"\n")
#     print("ap",apple,"\n")
#     print("v",vudu,"\n")
#     print("g",google,"\n")

    # Fillind the general dict,so that the code is independent of any particular portal
    if(amazon_class==0):
        general = amazon.copy()
    elif(itunes_class==0):
        general = itunes.copy()
    elif(appletv_class==0):
        general = apple.copy()
    elif(google_class==0):
        general = google.copy()
    elif(vudu_class==0):
        general = vudu.copy()
        
    
#     print(general).

# Check whether the name and corresponding number of each episode is same or not
    y=0  
    z = len_
    if(appletv_class==0):
        for i in range(1,z+1):
            m=token(general[str(i)])
            n=token(apple[str(i)])            
            if(n.find(m)!=-1):
                y=y+1
            print(f"general:{m} apple:{n}")
            print(y)
            
    #print(y)        
    print("\n")
    if(google_class==0):
        for i in range(1,z+1):
            m=token(general[str(i)])
            n=token(google[str(i)])
            if(n.find(m)!=-1):
                y=y+1
            print(f"general:{m} google:{n}")
            print(y)
    
    #print(y)
    print("\n")
    if(itunes_class==0):
        for i in range(1,z+1):
            m=token(general[str(i)])
            n=token(itunes[str(i)])
            if(n.find(m)!=-1):
                y=y+1
            print(f"general:{m} itunes:{n}")
            print(y)
    
    #print(y)
    print("\n")
    if(vudu_class==0):
        for i in range(1,z+1):
            m=token(general[str(i)])
            n=token(vudu[str(i)])
            if(n.find(m)!=-1):
                y=y+1
            print(f"general:{m} vudu:{n}")
            print(y)
    
    #print(y)
    print("\n")
    if(amazon_class==0):
        for i in range(1,z+1):
            m=token(general[str(i)])
            n=token(amazon[str(i)])
            if(n.find(m)!=-1):
                y=y+1
            print(f"general:{m} amazon:{n}")
            print(y)
            

    print(f"y:{y}")
    print(f"x:{x}")
    
    #  If episode number and corresponding name are same then print properly mapped else vice versa
    if(x==5 and y==((5-(amazon_class+itunes_class+appletv_class+vudu_class+google_class))*len_)):
        print("\033[1mProperly Mapped\033[0m")
    else:
        print("\033[1mNot Properly Mapped\033[0m")
# Out:
#  Test Case:  3
# Amazon portal is not there.
# Google portal is not there.
# len= 36
# iTunes length is not same
# Vudu length is not same
# Not Properly Mapped Due to Size
#
#  Test Case:  4
# Google portal is not there.
# len= 13
# general:pilot apple:pilot
# 1
# general:defiance apple:defiance
# 2
# general:conair apple:conair
# 3
# general:djvu apple:djvu
# 4
# general:farewell apple:farewell
# 5
# general:mylovely apple:mylovely
# 6
# general:bookofsecrets apple:bookofsecrets
# 7
# general:deadmentellnotales apple:deadmentellnotales
# 8
# general:dangerousminds apple:dangerousminds
# 9
# general:enemyofthestate apple:enemyofthestate
# 10
# general:thief apple:thief
# 11
# general:armageddon apple:armageddon
# 12
# general:badgirls apple:badgirls
# 13
#
#
#
#
# general:pilot itunes:pilot
# 14
# general:defiance itunes:defiance
# 15
# general:conair itunes:conair
# 16
# general:djvu itunes:djvu
# 17
# general:farewell itunes:farewell
# 18
# general:mylovely itunes:mylovely
# 19
# general:bookofsecrets itunes:bookofsecrets
# 20
# general:deadmentellnotales itunes:deadmentellnotales
# 21
# general:dangerousminds itunes:dangerousminds
# 22
# general:enemyofthestate itunes:enemyofthestate
# 23
# general:thief itunes:thief
# 24
# general:armageddon itunes:armageddon
# 25
# general:badgirls itunes:badgirls
# 26
#
#
# general:pilot vudu:lasfinestpilot
# 27
# general:defiance vudu:lasfinestdefiance
# 28
# general:conair vudu:lasfinestconair
# 29
# general:djvu vudu:lasfinestdejavu
# 29
# general:farewell vudu:lasfinestfarwell
# 29
# general:mylovely vudu:lasfinestmylovely
# 30
# general:bookofsecrets vudu:lasfinestbookofsecrets
# 31
# general:deadmentellnotales vudu:lasfinestdeadmentellnotales
# 32
# general:dangerousminds vudu:lasfinestdangerousminds
# 33
# general:enemyofthestate vudu:lasfinestenemyofthestate
# 34
# general:thief vudu:lasfinestthief
# 35
# general:armageddon vudu:lasfinestarmageddon
# 36
# general:badgirls vudu:lasfinestbadgirls
# 37
#
#
# general:pilot amazon:pilot
# 38
# general:defiance amazon:defiance
# 39
# general:conair amazon:conair
# 40
# general:djvu amazon:djvu
# 41
# general:farewell amazon:farewell
# 42
# general:mylovely amazon:mylovely
# 43
# general:bookofsecrets amazon:bookofsecrets
# 44
# general:deadmentellnotales amazon:deadmentellnotales
# 45
# general:dangerousminds amazon:dangerousminds
# 46
# general:enemyofthestate amazon:enemyofthestate
# 47
# general:thief amazon:thief
# 48
# general:armageddon amazon:armageddon
# 49
# general:badgirls amazon:badgirls
# 50
# y:50
# x:4
# Not Properly Mapped
#
#  Test Case:  5
# Amazon portal is not there.
# Google portal is not there.
# len= 20
# Apple length is not same
# Vudu length is not same
# Not Properly Mapped Due to Size
#
#  Test Case:  6
# Amazon portal is not there.
# len= 10
# general:badhairbotday apple:badhairbotday
# 1
# general:blairsappointment apple:blairsappointment
# 2
# general:allatsea apple:allatsea
# 3
# general:doubletrouble apple:doubletrouble
# 4
# general:theflowerparade apple:theflowerparade
# 5
# general:ahairysituation apple:ahairysituation
# 6
# general:chasingrainbows apple:chasingrainbows
# 7
# general:blairsdayoff apple:blairsdayoff
# 8
# general:pinpals apple:pinpals
# 9
# general:sunnyandthefireworksfestival apple:sunnyandthefireworksfestival
# 10
#
#
# general:badhairbotday google:badhairbotday
# 11
# general:blairsappointment google:blairsappointment
# 12
# general:allatsea google:allatsea
# 13
# general:doubletrouble google:doubletrouble
# 14
# general:theflowerparade google:theflowerparade
# 15
# general:ahairysituation google:ahairysituation
# 16
# general:chasingrainbows google:chasingrainbows
# 17
# general:blairsdayoff google:blairsdayoff
# 18
# general:pinpals google:pinpals
# 19
# general:sunnyandthefireworksfestival google:sunnyandthefireworksfestival
# 20
#
#
# general:badhairbotday itunes:badhairbotday
# 21
# general:blairsappointment itunes:blairsappointment
# 22
# general:allatsea itunes:allatsea
# 23
# general:doubletrouble itunes:doubletrouble
# 24
# general:theflowerparade itunes:theflowerparade
# 25
# general:ahairysituation itunes:ahairysituation
# 26
# general:chasingrainbows itunes:chasingrainbows
# 27
# general:blairsdayoff itunes:blairsdayoff
# 28
# general:pinpals itunes:pinpals
# 29
# general:sunnyandthefireworksfestival itunes:sunnyandthefireworksfestival
# 30
#
#
# general:badhairbotday vudu:sunnydaybadhairbotday
# 31
# general:blairsappointment vudu:sunnydayblairsappointment
# 32
# general:allatsea vudu:sunnydayallatsea
# 33
# general:doubletrouble vudu:sunnydaydoubletrouble
# 34
# general:theflowerparade vudu:sunnydaytheflowerparade
# 35
# general:ahairysituation vudu:sunnydayahairysituation
# 36
# general:chasingrainbows vudu:sunnydaychasingrainbows
# 37
# general:blairsdayoff vudu:sunnydayblairsdayoff
# 38
# general:pinpals vudu:sunnydaypinpals
# 39
# general:sunnyandthefireworksfestival vudu:sunnydaysunnyandthefireworksfestival
# 40
#
#
# y:40
# x:4
# Not Properly Mapped
#
#  Test Case:  7
# Amazon portal is not there.
# len= 10
# general:thetaleofharoldhorpus apple:thetaleofharoldhorpus
# 1
# general:aflintlockahound apple:aflintlockahound
# 2
# general:theemboldenedconflict apple:theemboldenedconflict
# 3
# general:ontheprinciplesofhorsehound apple:ontheprinciplesofhorsehound
# 4
# general:thetiniestbattle apple:thetiniestbattle
# 5
# general:forloveofthearchipelago apple:theprincipledbattleofthearchipelago
# 5
# general:25or6to4 apple:25or6to4
# 6
# general:thehorsecabbageheart apple:thehorsecabbageheart
# 7
# general:dammit apple:dammit
# 8
# general:thehorpushorrendous apple:thehorpushorrendous
# 9
#
#
# general:thetaleofharoldhorpus google:thetaleofharoldhorpus
# 10
# general:aflintlockahound google:aflintlockahound
# 11
# general:theemboldenedconflict google:theemboldenedconflict
# 12
# general:ontheprinciplesofhorsehound google:ontheprinciplesofhorsehound
# 13
# general:thetiniestbattle google:thetiniestbattle
# 14
# general:forloveofthearchipelago google:theprincipledbattleofthearchipelago
# 14
# general:25or6to4 google:25or6to4
# 15
# general:thehorsecabbageheart google:thehorsecabbageheart
# 16
# general:dammit google:dammit
# 17
# general:thehorpushorrendous google:thehorpushorrendous
# 18
#
#
# general:thetaleofharoldhorpus itunes:thetaleofharoldhorpus
# 19
# general:aflintlockahound itunes:aflintlockahound
# 20
# general:theemboldenedconflict itunes:theemboldenedconflict
# 21
# general:ontheprinciplesofhorsehound itunes:ontheprinciplesofhorsehound
# 22
# general:thetiniestbattle itunes:thetiniestbattle
# 23
# general:forloveofthearchipelago itunes:forloveofthearchipelago
# 24
# general:25or6to4 itunes:25or6to4
# 25
# general:thehorsecabbageheart itunes:thehorsecabbageheart
# 26
# general:dammit itunes:dammit
# 27
# general:thehorpushorrendous itunes:thehorpushorrendous
# 28
#
#
# general:thetaleofharoldhorpus vudu:reprisalthetaleofharoldhorpus
# 29
# general:aflintlockahound vudu:reprisalaflintlockahound
# 30
# general:theemboldenedconflict vudu:reprisaltheemboldenedconflict
# 31
# general:ontheprinciplesofhorsehound vudu:reprisalontheprinciplesofhorsehound
# 32
# general:thetiniestbattle vudu:reprisalthetiniestbattle
# 33
# general:forloveofthearchipelago vudu:reprisalforloveofthearchipelago
# 34
# general:25or6to4 vudu:reprisal25or6to4
# 35
# general:thehorsecabbageheart vudu:reprisalthehorsecabbageheart
# 36
# general:dammit vudu:reprisaldammit
# 37
# general:thehorpushorrendous vudu:reprisalthehorpushorrendous
# 38
#
#
# y:38
# x:4
# Not Properly Mapped
#
#  Test Case:  8
# len= 10
# general:meetthebuschfamily apple:meetthebuschfamily
# 1
# general:thesextalk apple:thesextalk
# 2
# general:jakesmakeover apple:jakesmakeover
# 3
# general:thebreak apple:thebreak
# 4
# general:buschstadiumclub apple:buschstadiumclub
# 5
# general:texassizedrama apple:texassizedrama
# 6
# general:themorningafter apple:themorningafter
# 7
# general:gussies23rdbirthday apple:gussies23rdbirthday
# 8
# general:thenextsteps apple:thenextsteps
# 9
# general:groundbreaking apple:groundbreaking
# 10
#
#
# general:meetthebuschfamily google:meetthebuschfamily
# 11
# general:thesextalk google:thesextalk
# 12
# general:jakesmakeover google:jakesmakeover
# 13
# general:thebreak google:thebreak
# 14
# general:buschstadiumclub google:buschstadiumclub
# 15
# general:texassizedrama google:texassizedrama
# 16
# general:themorningafter google:themorningafter
# 17
# general:gussies23rdbirthday google:gussies23rdbirthday
# 18
# general:thenextsteps google:thenextsteps
# 19
# general:groundbreaking google:groundbreaking
# 20
#
#
# general:meetthebuschfamily itunes:meetthebuschfamily
# 21
# general:thesextalk itunes:thesextalk
# 22
# general:jakesmakeover itunes:jakesmakeover
# 23
# general:thebreak itunes:thebreak
# 24
# general:buschstadiumclub itunes:buschstadiumclub
# 25
# general:texassizedrama itunes:texassizedrama
# 26
# general:themorningafter itunes:themorningafter
# 27
# general:gussies23rdbirthday itunes:gussies23rdbirthday
# 28
# general:thenextsteps itunes:thenextsteps
# 29
# general:groundbreaking itunes:groundbreaking
# 30
#
#
# general:meetthebuschfamily vudu:thebuschfamilybrewedmeetthebuschfamily
# 31
# general:thesextalk vudu:thebuschfamilybrewedthesextalk
# 32
# general:jakesmakeover vudu:thebuschfamilybrewedjakesmakeover
# 33
# general:thebreak vudu:thebuschfamilybrewedthebreak
# 34
# general:buschstadiumclub vudu:thebuschfamilybrewedbuschstadiumclub
# 35
# general:texassizedrama vudu:thebuschfamilybrewedtexassizedrama
# 36
# general:themorningafter vudu:thebuschfamilybrewedthemorningafter
# 37
# general:gussies23rdbirthday vudu:thebuschfamilybrewedgussies23rdbirthday
# 38
# general:thenextsteps vudu:thebuschfamilybrewedthenextsteps
# 39
# general:groundbreaking vudu:thebuschfamilybrewedgroundbreaking
# 40
#
#
# general:meetthebuschfamily amazon:meetthebuschfamily
# 41
# general:thesextalk amazon:thesextalk
# 42
# general:jakesmakeover amazon:jakesmakeover
# 43
# general:thebreak amazon:thebreak
# 44
# general:buschstadiumclub amazon:buschstadiumclub
# 45
# general:texassizedrama amazon:texassizedrama
# 46
# general:themorningafter amazon:themorningafter
# 47
# general:gussies23rdbirthday amazon:gussies23rdbirthday
# 48
# general:thenextsteps amazon:thenextsteps
# 49
# general:groundbreaking amazon:groundbreaking
# 50
# y:50
# x:5
# Properly Mapped
#
#  Test Case:  9
# len= 6
# general:backfromthedead apple:disasterstrikes
# 0
# general:disasterstrikes apple:bleedingout
# 0
# general:bleedingout apple:backfromthedead
# 0
# general:lostatsea apple:lostatsea
# 1
# general:sunkensurvivor apple:sunkensurvivor
# 2
# general:hoistedfromhell apple:hoistedfromhell
# 3
#
#
# general:backfromthedead google:backfromthedead
# 4
# general:disasterstrikes google:disasterstrikes
# 5
# general:bleedingout google:bleedingout
# 6
# general:lostatsea google:lostatsea
# 7
# general:sunkensurvivor google:sunkensurvivor
# 8
# general:hoistedfromhell google:hoistedfromhell
# 9
#
#
# general:backfromthedead itunes:backfromthedead
# 10
# general:disasterstrikes itunes:disasterstrikes
# 11
# general:bleedingout itunes:bleedingout
# 12
# general:lostatsea itunes:lostatsea
# 13
# general:sunkensurvivor itunes:sunkensurvivor
# 14
# general:hoistedfromhell itunes:hoistedfromhell
# 15
#
#
# general:backfromthedead vudu:extremerescuesbackfromthedead
# 16
# general:disasterstrikes vudu:extremerescuesdisasterstrikes
# 17
# general:bleedingout vudu:extremerescuesbleedingout
# 18
# general:lostatsea vudu:extremerescueslostatsea
# 19
# general:sunkensurvivor vudu:extremerescuessunkensurvivor
# 20
# general:hoistedfromhell vudu:extremerescueshoistedfromhell
# 21
#
#
# general:backfromthedead amazon:backfromthedead
# 22
# general:disasterstrikes amazon:disasterstrikes
# 23
# general:bleedingout amazon:bleedingout
# 24
# general:lostatsea amazon:lostatsea
# 25
# general:sunkensurvivor amazon:sunkensurvivor
# 26
# general:hoistedfromhell amazon:hoistedfromhell
# 27
# y:27
# x:5
# Not Properly Mapped
#
#  Test Case:  10
# len= 8
# general:camp apple:camp
# 1
# general:kevin apple:kevin
# 2
# general:skate apple:skate
# 3
# general:freak apple:freak
# 4
# general:wedding apple:wedding
# 5
# general:waham apple:waham
# 6
# general:salon apple:salon
# 7
# general:hr apple:hr
# 8
#
#
# general:camp google:camp
# 9
# general:kevin google:kevin
# 10
# general:skate google:skate
# 11
# general:freak google:freak
# 12
# general:wedding google:wedding
# 13
# general:waham google:waham
# 14
# general:salon google:salon
# 15
# general:hr google:hr
# 16
#
#
# general:camp itunes:camp
# 17
# general:kevin itunes:kevin
# 18
# general:skate itunes:skate
# 19
# general:freak itunes:freak
# 20
# general:wedding itunes:wedding
# 21
# general:waham itunes:waham
# 22
# general:salon itunes:salon
# 23
# general:hr itunes:hr
# 24
#
#
# general:camp vudu:shrillcamp
# 25
# general:kevin vudu:shrillkevin
# 26
# general:skate vudu:shrillskate
# 27
# general:freak vudu:shrillfreak
# 28
# general:wedding vudu:shrillwedding
# 29
# general:waham vudu:shrillwaham
# 30
# general:salon vudu:shrillsalon
# 31
# general:hr vudu:shrillhr
# 32
#
#
# general:camp amazon:camp
# 33
# general:kevin amazon:kevin
# 34
# general:skate amazon:skate
# 35
# general:freak amazon:freak
# 36
# general:wedding amazon:wedding
# 37
# general:waham amazon:waham
# 38
# general:salon amazon:salon
# 39
# general:hr amazon:hr
# 40
# y:40
# x:5
# Properly Mapped
#
#  Test Case:  11
# Vudu portal is not there.
# len= 13
# general:chasingwinerydreams apple:chasingwinerydreams
# 1
# general:bankingonmontenegrosboom apple:bankingonmontenegrosboom
# 2
# general:familyhomeinvietnam apple:familyhomeinvietnam
# 3
# general:badtothebadenwurttemberg apple:badtothebadenwurttemberg
# 4
# general:torentornotinaruba apple:torentornotinaruba
# 5
# general:petpeevesinbelize apple:petpeevesinbelize
# 6
# general:keepguamandcarryon apple:keepguamandcarryon
# 7
# general:underthetuscanguninitaly apple:underthetuscanguninitaly
# 8
# general:agreekdreamcometrue apple:agreekdreamcometrue
# 9
# general:aswedepadinstockholm apple:aswedepadinstockholm
# 10
# general:amsterdamthetorpedoes apple:amsterdamthetorpedoes
# 11
# general:surprisemovetomexico apple:surprisemovetomexico
# 12
# general:triestetravelorbudgetbust apple:triestetravelorbudgetbust
# 13
#
#
# general:chasingwinerydreams google:chasingwinerydreams
# 14
# general:bankingonmontenegrosboom google:bankingonmontenegrosboom
# 15
# general:familyhomeinvietnam google:familyhomeinvietnam
# 16
# general:badtothebadenwurttemberg google:badtothebadenwurttemberg
# 17
# general:torentornotinaruba google:torentornotinaruba
# 18
# general:petpeevesinbelize google:petpeevesinbelize
# 19
# general:keepguamandcarryon google:keepguamandcarryon
# 20
# general:underthetuscanguninitaly google:underthetuscanguninitaly
# 21
# general:agreekdreamcometrue google:agreekdreamcometrue
# 22
# general:aswedepadinstockholm google:aswedepadinstockholm
# 23
# general:amsterdamthetorpedoes google:amsterdamthetorpedoes
# 24
# general:surprisemovetomexico google:surprisemovetomexico
# 25
# general:triestetravelorbudgetbust google:triestetravelorbudgetbust
# 26
#
#
# general:chasingwinerydreams itunes:chasingwinerydreams
# 27
# general:bankingonmontenegrosboom itunes:bankingonmontenegrosboom
# 28
# general:familyhomeinvietnam itunes:familyhomeinvietnam
# 29
# general:badtothebadenwurttemberg itunes:badtothebadenwurttemberg
# 30
# general:torentornotinaruba itunes:torentornotinaruba
# 31
# general:petpeevesinbelize itunes:petpeevesinbelize
# 32
# general:keepguamandcarryon itunes:keepguamandcarryon
# 33
# general:underthetuscanguninitaly itunes:underthetuscanguninitaly
# 34
# general:agreekdreamcometrue itunes:agreekdreamcometrue
# 35
# general:aswedepadinstockholm itunes:aswedepadinstockholm
# 36
# general:amsterdamthetorpedoes itunes:amsterdamthetorpedoes
# 37
# general:surprisemovetomexico itunes:surprisemovetomexico
# 38
# general:triestetravelorbudgetbust itunes:triestetravelorbudgetbust
# 39
#
#
#
#
# general:chasingwinerydreams amazon:chasingwinerydreams
# 40
# general:bankingonmontenegrosboom amazon:bankingonmontenegrosboom
# 41
# general:familyhomeinvietnam amazon:familyhomeinvietnam
# 42
# general:badtothebadenwurttemberg amazon:badtothebadenwurttemberg
# 43
# general:torentornotinaruba amazon:torentornotinaruba
# 44
# general:petpeevesinbelize amazon:petpeevesinbelize
# 45
# general:keepguamandcarryon amazon:keepguamandcarryon
# 46
# general:underthetuscanguninitaly amazon:underthetuscanguninitaly
# 47
# general:agreekdreamcometrue amazon:agreekdreamcometrue
# 48
# general:aswedepadinstockholm amazon:aswedepadinstockholm
# 49
# general:amsterdamthetorpedoes amazon:amsterdamthetorpedoes
# 50
# general:surprisemovetomexico amazon:surprisemovetomexico
# 51
# general:triestetravelorbudgetbust amazon:triestetravelorbudgetbust
# 52
# y:52
# x:4
# Not Properly Mapped
#
#  Test Case:  12
# Vudu portal is not there.
# len= 13
# Amazon length is not same
# Not Properly Mapped Due to Size
#
#  Test Case:  13
# Amazon portal is not there.
# Vudu portal is not there.
# Google portal is not there.
# len= 6
# general:episode1 apple:episode1
# 1
# general:episode2 apple:episode2
# 2
# general:episode3 apple:episode3
# 3
# general:episode4 apple:episode4
# 4
# general:episode5 apple:episode5
# 5
# general:episode6 apple:episode6
# 6
#
#
#
#
# general:episode1 itunes:episode1
# 7
# general:episode2 itunes:episode2
# 8
# general:episode3 itunes:episode3
# 9
# general:episode4 itunes:episode4
# 10
# general:episode5 itunes:episode5
# 11
# general:episode6 itunes:episode6
# 12
#
#
#
#
# y:12
# x:2
# Not Properly Mapped
#
#  Test Case:  14
# len= 12
# general:horrorinbiggs apple:horrorinbiggs
# 1
# general:franklincastle apple:franklincastle
# 2
# general:unionbreweryofdeath apple:unionbreweryofdeath
# 3
# general:nightmareinantelope apple:antelopenightmare
# 3
# general:goodwinhomeinvasion apple:goodwinhomeinvasion
# 4
# general:hauntedhollowforest apple:hauntedhollowforest
# 5
# general:thechinatownpoltergeist apple:thechinatownpoltergeist
# 6
# general:beneaththebonanza apple:beneaththebonanza
# 7
# general:districtofthedamned apple:districtofthedamned
# 8
# general:londonbridge apple:londonbridge
# 9
# general:thegraberfarmentity apple:thegraberfarmentity
# 10
# general:bloodshedinthebordello apple:bloodshedinthebordello
# 11
#
#
# general:horrorinbiggs google:horrorinbiggs
# 12
# general:franklincastle google:franklincastle
# 13
# general:unionbreweryofdeath google:unionbreweryofdeath
# 14
# general:nightmareinantelope google:nightmareinantelope
# 15
# general:goodwinhomeinvasion google:goodwinhomeinvasion
# 16
# general:hauntedhollowforest google:hauntedhollowforest
# 17
# general:thechinatownpoltergeist google:thechinatownpoltergeist
# 18
# general:beneaththebonanza google:beneaththebonanza
# 19
# general:districtofthedamned google:districtofthedamned
# 20
# general:londonbridge google:londonbridge
# 21
# general:thegraberfarmentity google:thegraberfarmentity
# 22
# general:bloodshedinthebordello google:bloodshedinthebordello
# 23
#
#
# general:horrorinbiggs itunes:horrorinbiggs
# 24
# general:franklincastle itunes:franklincastle
# 25
# general:unionbreweryofdeath itunes:unionbreweryofdeath
# 26
# general:nightmareinantelope itunes:nightmareinantelope
# 27
# general:goodwinhomeinvasion itunes:goodwinhomeinvasion
# 28
# general:hauntedhollowforest itunes:hauntedhollowforest
# 29
# general:thechinatownpoltergeist itunes:thechinatownpoltergeist
# 30
# general:beneaththebonanza itunes:beneaththebonanza
# 31
# general:districtofthedamned itunes:districtofthedamned
# 32
# general:londonbridge itunes:londonbridge
# 33
# general:thegraberfarmentity itunes:thegraberfarmentity
# 34
# general:bloodshedinthebordello itunes:bloodshedinthebordello
# 35
#
#
# general:horrorinbiggs vudu:ghostadventureshorrorinbiggs
# 36
# general:franklincastle vudu:ghostadventuresfranklincastle
# 37
# general:unionbreweryofdeath vudu:ghostadventuresunionbreweryofdeath
# 38
# general:nightmareinantelope vudu:ghostadventuresnightmareinantelope
# 39
# general:goodwinhomeinvasion vudu:ghostadventuresgoodwinhomeinvasion
# 40
# general:hauntedhollowforest vudu:ghostadventureshauntedhollowforest
# 41
# general:thechinatownpoltergeist vudu:ghostadventuresthechinatownpoltergeist
# 42
# general:beneaththebonanza vudu:ghostadventuresbeneaththebonanza
# 43
# general:districtofthedamned vudu:ghostadventuresdistrictofthedamned
# 44
# general:londonbridge vudu:ghostadventureslondonbridge
# 45
# general:thegraberfarmentity vudu:ghostadventuresthegraberfarmentity
# 46
# general:bloodshedinthebordello vudu:ghostadventuresbloodshedinthebordello
# 47
#
#
# general:horrorinbiggs amazon:horrorinbiggs
# 48
# general:franklincastle amazon:franklincastle
# 49
# general:unionbreweryofdeath amazon:unionbreweryofdeath
# 50
# general:nightmareinantelope amazon:nightmareinantelope
# 51
# general:goodwinhomeinvasion amazon:goodwinhomeinvasion
# 52
# general:hauntedhollowforest amazon:hauntedhollowforest
# 53
# general:thechinatownpoltergeist amazon:thechinatownpoltergeist
# 54
# general:beneaththebonanza amazon:beneaththebonanza
# 55
# general:districtofthedamned amazon:districtofthedamned
# 56
# general:londonbridge amazon:londonbridge
# 57
# general:thegraberfarmentity amazon:thegraberfarmentity
# 58
# general:bloodshedinthebordello amazon:bloodshedinthebordello
# 59
# y:59
# x:5
# Not Properly Mapped
#
#  Test Case:  15
# Vudu portal is not there.
# len= 13
# general:lowbudgetbluesinmemphis apple:lowbudgetbluesinmemphis
# 1
# general:startingoverinkansascity apple:troubleinthejerseyburbs
# 1
# general:milehighexpectations apple:seekingairspaceindc
# 1
# general:pickyaboutpriceinnj apple:mustbequirkyinmichigan
# 1
# general:itchingformoreroominindy apple:milehighexpectations
# 1
# general:honoluluhousehunt apple:itchingformoreroominindy
# 1
# general:troubleinthejerseyburbs apple:pickyaboutpriceinnj
# 1
# general:mustbequirkyinmichigan apple:napavalleydreamhome
# 1
# general:napavalleydreamhome apple:startingoverinkansascity
# 1
# general:seekingairspaceindc apple:downtownchicagolofthunt
# 1
# general:downtownchicagolofthunt apple:frenchflairinhouston
# 1
# general:frenchflairinhouston apple:honoluluhousehunt
# 1
# general:bighouseorbiglotinaustin apple:bighouseorbiglotinaustin
# 2
#
#
# general:lowbudgetbluesinmemphis google:lowbudgetbluesinmemphis
# 3
# general:startingoverinkansascity google:startingoverinkansascity
# 4
# general:milehighexpectations google:milehighexpectations
# 5
# general:pickyaboutpriceinnj google:pickyaboutpriceinnj
# 6
# general:itchingformoreroominindy google:itchingformoreroominindy
# 7
# general:honoluluhousehunt google:honoluluhousehunt
# 8
# general:troubleinthejerseyburbs google:troubleinthejerseyburbs
# 9
# general:mustbequirkyinmichigan google:mustbequirkyinmichigan
# 10
# general:napavalleydreamhome google:napavalleydreamhome
# 11
# general:seekingairspaceindc google:seekingairspaceindc
# 12
# general:downtownchicagolofthunt google:downtownchicagolofthunt
# 13
# general:frenchflairinhouston google:frenchflairinhouston
# 14
# general:bighouseorbiglotinaustin google:bighouseorbiglotinaustin
# 15
#
#
# general:lowbudgetbluesinmemphis itunes:lowbudgetbluesinmemphis
# 16
# general:startingoverinkansascity itunes:startingoverinkansascity
# 17
# general:milehighexpectations itunes:milehighexpectations
# 18
# general:pickyaboutpriceinnj itunes:pickyaboutpriceinnj
# 19
# general:itchingformoreroominindy itunes:itchingformoreroominindy
# 20
# general:honoluluhousehunt itunes:honoluluhousehunt
# 21
# general:troubleinthejerseyburbs itunes:troubleinthejerseyburbs
# 22
# general:mustbequirkyinmichigan itunes:mustbequirkyinmichigan
# 23
# general:napavalleydreamhome itunes:napavalleydreamhome
# 24
# general:seekingairspaceindc itunes:seekingairspaceindc
# 25
# general:downtownchicagolofthunt itunes:downtownchicagolofthunt
# 26
# general:frenchflairinhouston itunes:frenchflairinhouston
# 27
# general:bighouseorbiglotinaustin itunes:bighouseorbiglotinaustin
# 28
#
#
#
#
# general:lowbudgetbluesinmemphis amazon:lowbudgetbluesinmemphis
# 29
# general:startingoverinkansascity amazon:startingoverinkansascity
# 30
# general:milehighexpectations amazon:milehighexpectations
# 31
# general:pickyaboutpriceinnj amazon:pickyaboutpriceinnj
# 32
# general:itchingformoreroominindy amazon:itchingformoreroominindy
# 33
# general:honoluluhousehunt amazon:honoluluhousehunt
# 34
# general:troubleinthejerseyburbs amazon:troubleinthejerseyburbs
# 35
# general:mustbequirkyinmichigan amazon:mustbequirkyinmichigan
# 36
# general:napavalleydreamhome amazon:napavalleydreamhome
# 37
# general:seekingairspaceindc amazon:seekingairspaceindc
# 38
# general:downtownchicagolofthunt amazon:downtownchicagolofthunt
# 39
# general:frenchflairinhouston amazon:frenchflairinhouston
# 40
# general:bighouseorbiglotinaustin amazon:bighouseorbiglotinaustin
# 41
# y:41
# x:4
# Not Properly Mapped
#
#  Test Case:  16
# Vudu portal is not there.
# len= 13
# Apple length is not same
# Not Properly Mapped Due to Size
#
#  Test Case:  17
# Vudu portal is not there.
# len= 13
# general:grandonabudgetinatlanta apple:downtowntosuburbanstlouis
# 0
# general:tobuildornottobuildinok apple:tobuildornottobuildinok
# 1
# general:chasingdreamsinnashville apple:pitchedbattleinvegas
# 1
# general:downtowntosuburbanstlouis apple:highpriceofparadise
# 1
# general:loftorrowhomeinphilly apple:strongviewsinstrongsville
# 1
# general:strongviewsinstrongsville apple:wewannabejerseyboys
# 1
# general:highpriceofparadise apple:loftorrowhomeinphilly
# 1
# general:wantingitallinatlanta apple:chasingdreamsinnashville
# 1
# general:arowoverarowhuntindc apple:wantingitallinatlanta
# 1
# general:wewannabejerseyboys apple:dramaindallas
# 1
# general:emptynestersgodowntown apple:arowoverarowhuntindc
# 1
# general:dramaindallas apple:emptynestersgodowntown
# 1
# general:pitchedbattleinvegas apple:grandonabudgetinatlanta
# 1
#
#
# general:grandonabudgetinatlanta google:grandonabudgetinatlanta
# 2
# general:tobuildornottobuildinok google:tobuildornottobuildinok
# 3
# general:chasingdreamsinnashville google:chasingdreamsinnashville
# 4
# general:downtowntosuburbanstlouis google:downtowntosuburbanstlouis
# 5
# general:loftorrowhomeinphilly google:loftorrowhomeinphilly
# 6
# general:strongviewsinstrongsville google:strongviewsinstrongsville
# 7
# general:highpriceofparadise google:highpriceofparadise
# 8
# general:wantingitallinatlanta google:wantingitallinatlanta
# 9
# general:arowoverarowhuntindc google:arowoverarowhuntindc
# 10
# general:wewannabejerseyboys google:wewannabejerseyboys
# 11
# general:emptynestersgodowntown google:emptynestersgodowntown
# 12
# general:dramaindallas google:dramaindallas
# 13
# general:pitchedbattleinvegas google:pitchedbattleinvegas
# 14
#
#
# general:grandonabudgetinatlanta itunes:grandonabudgetinatlanta
# 15
# general:tobuildornottobuildinok itunes:tobuildornottobuildinok
# 16
# general:chasingdreamsinnashville itunes:chasingdreamsinnashville
# 17
# general:downtowntosuburbanstlouis itunes:downtowntosuburbanstlouis
# 18
# general:loftorrowhomeinphilly itunes:loftorrowhomeinphilly
# 19
# general:strongviewsinstrongsville itunes:strongviewsinstrongsville
# 20
# general:highpriceofparadise itunes:highpriceofparadise
# 21
# general:wantingitallinatlanta itunes:wantingitallinatlanta
# 22
# general:arowoverarowhuntindc itunes:arowoverarowhuntindc
# 23
# general:wewannabejerseyboys itunes:wewannabejerseyboys
# 24
# general:emptynestersgodowntown itunes:emptynestersgodowntown
# 25
# general:dramaindallas itunes:dramaindallas
# 26
# general:pitchedbattleinvegas itunes:pitchedbattleinvegas
# 27
#
#
#
#
# general:grandonabudgetinatlanta amazon:grandonabudgetinatlanta
# 28
# general:tobuildornottobuildinok amazon:tobuildornottobuildinok
# 29
# general:chasingdreamsinnashville amazon:chasingdreamsinnashville
# 30
# general:downtowntosuburbanstlouis amazon:downtowntosuburbanstlouis
# 31
# general:loftorrowhomeinphilly amazon:loftorrowhomeinphilly
# 32
# general:strongviewsinstrongsville amazon:strongviewsinstrongsville
# 33
# general:highpriceofparadise amazon:highpriceofparadise
# 34
# general:wantingitallinatlanta amazon:wantingitallinatlanta
# 35
# general:arowoverarowhuntindc amazon:arowoverarowhuntindc
# 36
# general:wewannabejerseyboys amazon:wewannabejerseyboys
# 37
# general:emptynestersgodowntown amazon:emptynestersgodowntown
# 38
# general:dramaindallas amazon:dramaindallas
# 39
# general:pitchedbattleinvegas amazon:pitchedbattleinvegas
# 40
# y:40
# x:4
# Not Properly Mapped
#
#  Test Case:  18
# Vudu portal is not there.
# len= 13
# general:hawaiiherewecome apple:battleovertheburbs
# 0
# general:battleovertheburbs apple:movingtoatlanticcity
# 0
# general:movingtoatlanticcity apple:housedebateindc
# 0
# general:winterwindsinconnecticut apple:winterwindsinconnecticut
# 1
# general:housedebateindc apple:hawaiianstyleinvirginia
# 1
# general:hawaiianstyleinvirginia apple:realestateagentvswife
# 1
# general:realestateagentvswife apple:runningfromrobbersinohio
# 1
# general:charmvsnewbuild apple:freshstartonatinybudget
# 1
# general:freshstartonatinybudget apple:acastlefortheking
# 1
# general:vintagedreamsinmichigan apple:hawaiiherewecome
# 1
# general:runningfromrobbersinohio apple:charmvsnewbuild
# 1
# general:dukingitoutindallas apple:vintagedreamsinmichigan
# 1
# general:acastlefortheking apple:dukingitoutindallas
# 1
#
#
# general:hawaiiherewecome google:hawaiiherewecome
# 2
# general:battleovertheburbs google:battleovertheburbs
# 3
# general:movingtoatlanticcity google:movingtoatlanticcity
# 4
# general:winterwindsinconnecticut google:winterwindsinconnecticut
# 5
# general:housedebateindc google:housedebateindc
# 6
# general:hawaiianstyleinvirginia google:hawaiianstyleinvirginia
# 7
# general:realestateagentvswife google:realestateagentvswife
# 8
# general:charmvsnewbuild google:charmvsnewbuild
# 9
# general:freshstartonatinybudget google:freshstartonatinybudget
# 10
# general:vintagedreamsinmichigan google:vintagedreamsinmichigan
# 11
# general:runningfromrobbersinohio google:runningfromrobbersinohio
# 12
# general:dukingitoutindallas google:dukingitoutindallas
# 13
# general:acastlefortheking google:acastlefortheking
# 14
#
#
# general:hawaiiherewecome itunes:hawaiiherewecome
# 15
# general:battleovertheburbs itunes:battleovertheburbs
# 16
# general:movingtoatlanticcity itunes:movingtoatlanticcity
# 17
# general:winterwindsinconnecticut itunes:winterwindsinconnecticut
# 18
# general:housedebateindc itunes:housedebateindc
# 19
# general:hawaiianstyleinvirginia itunes:hawaiianstyleinvirginia
# 20
# general:realestateagentvswife itunes:realestateagentvswife
# 21
# general:charmvsnewbuild itunes:charmvsnewbuild
# 22
# general:freshstartonatinybudget itunes:freshstartonatinybudget
# 23
# general:vintagedreamsinmichigan itunes:vintagedreamsinmichigan
# 24
# general:runningfromrobbersinohio itunes:runningfromrobbersinohio
# 25
# general:dukingitoutindallas itunes:dukingitoutindallas
# 26
# general:acastlefortheking itunes:acastlefortheking
# 27
#
#
#
#
# general:hawaiiherewecome amazon:hawaiiherewecome
# 28
# general:battleovertheburbs amazon:battleovertheburbs
# 29
# general:movingtoatlanticcity amazon:movingtoatlanticcity
# 30
# general:winterwindsinconnecticut amazon:winterwindsinconnecticut
# 31
# general:housedebateindc amazon:housedebateindc
# 32
# general:hawaiianstyleinvirginia amazon:hawaiianstyleinvirginia
# 33
# general:realestateagentvswife amazon:realestateagentvswife
# 34
# general:charmvsnewbuild amazon:charmvsnewbuild
# 35
# general:freshstartonatinybudget amazon:freshstartonatinybudget
# 36
# general:vintagedreamsinmichigan amazon:vintagedreamsinmichigan
# 37
# general:runningfromrobbersinohio amazon:runningfromrobbersinohio
# 38
# general:dukingitoutindallas amazon:dukingitoutindallas
# 39
# general:acastlefortheking amazon:acastlefortheking
# 40
# y:40
# x:4
# Not Properly Mapped
#
#  Test Case:  19
# Vudu portal is not there.
# len= 13
# general:urbanvssuburbanindc apple:aimingforvintageinhouston
# 0
# general:woodsyvsmoderninarkansas apple:prettyorpracticalinphoenix
# 0
# general:momanddaughterinboise apple:momanddaughterinboise
# 1
# general:ruralhubbyvscitywife apple:urbanvssuburbanindc
# 1
# general:bostoncharmvsmoveinready apple:ruralhubbyvscitywife
# 1
# general:projectvsperfectinhouston apple:bostoncharmvsmoveinready
# 1
# general:dcareadreamhouse apple:dcareadreamhouse
# 2
# general:stlouiscool apple:tootallintampa
# 2
# general:firsttimebuyersinomaha apple:projectvsperfectinhouston
# 2
# general:aimingforvintageinhouston apple:woodsyvsmoderninarkansas
# 2
# general:fixervsupgradedinct apple:stlouiscool
# 2
# general:prettyorpracticalinphoenix apple:fixervsupgradedinct
# 2
# general:tootallintampa apple:firsttimebuyersinomaha
# 2
#
#
# general:urbanvssuburbanindc google:urbanvssuburbanindc
# 3
# general:woodsyvsmoderninarkansas google:woodsyvsmoderninarkansas
# 4
# general:momanddaughterinboise google:momanddaughterinboise
# 5
# general:ruralhubbyvscitywife google:ruralhubbyvscitywife
# 6
# general:bostoncharmvsmoveinready google:bostoncharmvsmoveinready
# 7
# general:projectvsperfectinhouston google:projectvsperfectinhouston
# 8
# general:dcareadreamhouse google:dcareadreamhouse
# 9
# general:stlouiscool google:stlouiscool
# 10
# general:firsttimebuyersinomaha google:firsttimebuyersinomaha
# 11
# general:aimingforvintageinhouston google:aimingforvintageinhouston
# 12
# general:fixervsupgradedinct google:fixervsupgradedinct
# 13
# general:prettyorpracticalinphoenix google:prettyorpracticalinphoenix
# 14
# general:tootallintampa google:tootallintampa
# 15
#
#
# general:urbanvssuburbanindc itunes:urbanvssuburbanindc
# 16
# general:woodsyvsmoderninarkansas itunes:woodsyvsmoderninarkansas
# 17
# general:momanddaughterinboise itunes:momanddaughterinboise
# 18
# general:ruralhubbyvscitywife itunes:ruralhubbyvscitywife
# 19
# general:bostoncharmvsmoveinready itunes:bostoncharmvsmoveinready
# 20
# general:projectvsperfectinhouston itunes:projectvsperfectinhouston
# 21
# general:dcareadreamhouse itunes:dcareadreamhouse
# 22
# general:stlouiscool itunes:stlouiscool
# 23
# general:firsttimebuyersinomaha itunes:firsttimebuyersinomaha
# 24
# general:aimingforvintageinhouston itunes:aimingforvintageinhouston
# 25
# general:fixervsupgradedinct itunes:fixervsupgradedinct
# 26
# general:prettyorpracticalinphoenix itunes:prettyorpracticalinphoenix
# 27
# general:tootallintampa itunes:tootallintampa
# 28
#
#
#
#
# general:urbanvssuburbanindc amazon:urbanvssuburbanindc
# 29
# general:woodsyvsmoderninarkansas amazon:woodsyvsmoderninarkansas
# 30
# general:momanddaughterinboise amazon:momanddaughterinboise
# 31
# general:ruralhubbyvscitywife amazon:ruralhubbyvscitywife
# 32
# general:bostoncharmvsmoveinready amazon:bostoncharmvsmoveinready
# 33
# general:projectvsperfectinhouston amazon:projectvsperfectinhouston
# 34
# general:dcareadreamhouse amazon:dcareadreamhouse
# 35
# general:stlouiscool amazon:stlouiscool
# 36
# general:firsttimebuyersinomaha amazon:firsttimebuyersinomaha
# 37
# general:aimingforvintageinhouston amazon:aimingforvintageinhouston
# 38
# general:fixervsupgradedinct amazon:fixervsupgradedinct
# 39
# general:prettyorpracticalinphoenix amazon:prettyorpracticalinphoenix
# 40
# general:tootallintampa amazon:tootallintampa
# 41
# y:41
# x:4
# Not Properly Mapped
#
#  Test Case:  20
# Vudu portal is not there.
# len= 13
# general:dublinsizematters apple:dublinsizematters
# 1
# general:livelavidalocalinecuador apple:livelavidalocalinecuador
# 2
# general:oppositesattractinoliva apple:oppositesattractinoliva
# 3
# general:noemptynestonnevis apple:noemptynestonnevis
# 4
# general:junglelove apple:junglelove
# 5
# general:businessbudgetbudapest apple:businessbudgetbudapest
# 6
# general:asecondchanceinamsterdam apple:asecondchanceinamsterdam
# 7
# general:beentherelondonthat apple:beentherelondonthat
# 8
# general:buenosdiasbarcelonaspain apple:buenosdiasbarcelonaspain
# 9
# general:belfastandfurious apple:belfastandfurious
# 10
# general:edsmagneticislandadventure apple:edsmagneticislandadventure
# 11
# general:newdigsindortmund apple:newdigsindortmund
# 12
# general:seekingnatureinaustria apple:seekingnatureinaustria
# 13
#
#
# general:dublinsizematters google:dublinsizematters
# 14
# general:livelavidalocalinecuador google:livelavidalocalinecuador
# 15
# general:oppositesattractinoliva google:oppositesattractinoliva
# 16
# general:noemptynestonnevis google:noemptynestonnevis
# 17
# general:junglelove google:junglelove
# 18
# general:businessbudgetbudapest google:businessbudgetbudapest
# 19
# general:asecondchanceinamsterdam google:asecondchanceinamsterdam
# 20
# general:beentherelondonthat google:beentherelondonthat
# 21
# general:buenosdiasbarcelonaspain google:buenosdiasbarcelonaspain
# 22
# general:belfastandfurious google:belfastandfurious
# 23
# general:edsmagneticislandadventure google:edsmagneticislandadventure
# 24
# general:newdigsindortmund google:newdigsindortmund
# 25
# general:seekingnatureinaustria google:seekingnatureinaustria
# 26
#
#
# general:dublinsizematters itunes:dublinsizematters
# 27
# general:livelavidalocalinecuador itunes:livelavidalocalinecuador
# 28
# general:oppositesattractinoliva itunes:oppositesattractinoliva
# 29
# general:noemptynestonnevis itunes:noemptynestonnevis
# 30
# general:junglelove itunes:junglelove
# 31
# general:businessbudgetbudapest itunes:businessbudgetbudapest
# 32
# general:asecondchanceinamsterdam itunes:asecondchanceinamsterdam
# 33
# general:beentherelondonthat itunes:beentherelondonthat
# 34
# general:buenosdiasbarcelonaspain itunes:buenosdiasbarcelonaspain
# 35
# general:belfastandfurious itunes:belfastandfurious
# 36
# general:edsmagneticislandadventure itunes:edsmagneticislandadventure
# 37
# general:newdigsindortmund itunes:newdigsindortmund
# 38
# general:seekingnatureinaustria itunes:seekingnatureinaustria
# 39
#
#
#
#
# general:dublinsizematters amazon:dublinsizematters
# 40
# general:livelavidalocalinecuador amazon:livelavidalocalinecuador
# 41
# general:oppositesattractinoliva amazon:oppositesattractinoliva
# 42
# general:noemptynestonnevis amazon:noemptynestonnevis
# 43
# general:junglelove amazon:junglelove
# 44
# general:businessbudgetbudapest amazon:businessbudgetbudapest
# 45
# general:asecondchanceinamsterdam amazon:asecondchanceinamsterdam
# 46
# general:beentherelondonthat amazon:beentherelondonthat
# 47
# general:buenosdiasbarcelonaspain amazon:buenosdiasbarcelonaspain
# 48
# general:belfastandfurious amazon:belfastandfurious
# 49
# general:edsmagneticislandadventure amazon:edsmagneticislandadventure
# 50
# general:newdigsindortmund amazon:newdigsindortmund
# 51
# general:seekingnatureinaustria amazon:seekingnatureinaustria
# 52
# y:52
# x:4
# Not Properly Mapped
#
#  Test Case:  21
# Vudu portal is not there.
# Google portal is not there.
# len= 20
# general:afirsttimeforeverything apple:afirsttimeforeverything
# 1
# general:abusybusinessandababybombshell apple:abusybusinessandababybombshell
# 2
# general:firsthomeandstrictchaperones apple:firsthomeandstrictchaperones
# 3
# general:happynewsandhealthconcerns apple:happynewsandhealthconcerns
# 4
# general:texasorbust apple:texasorbust
# 5
# general:surgeryandsurprises apple:surgeryandsurprises
# 6
# general:apizzakatiesheart apple:apizzakatiesheart
# 7
# general:agreatbatesgetaway apple:agreatbatesgetaway
# 8
# general:nestingmodemommiesonamission apple:nestingmodemommiesonamission
# 9
# general:takingcareofbusinessfloridafun apple:takingcareofbusinessfloridafun
# 10
# general:brandonsbookandkellyjosnewlook apple:brandonsbookandkellyjosnewlook
# 11
# general:holidaycheerandnewbabykhloeishere apple:holidaycheerandnewbabykhloeishere
# 12
# general:holidaytraditionsandbabyadditions apple:holidaytraditionsandbabyadditions
# 13
# general:roaringbatesandpendingduedates apple:roaringbatesandpendingduedates
# 14
# general:adoubledatesomethingtocelebrate apple:adoubledatesomethingtocelebrate
# 15
# general:beautyandthebusiness apple:beautyandthebusiness
# 16
# general:iloveyoutopizzas apple:iloveyoutopizzas
# 17
# general:theshowmustgoon apple:theshowmustgoon
# 18
# general:babyboyblessingsbasketballmishaps apple:babyboyblessingsbasketballmishaps
# 19
# general:shelterinbates apple:shelterinbates
# 20
#
#
#
#
# general:afirsttimeforeverything itunes:afirsttimeforeverything
# 21
# general:abusybusinessandababybombshell itunes:abusybusinessandababybombshell
# 22
# general:firsthomeandstrictchaperones itunes:firsthomeandstrictchaperones
# 23
# general:happynewsandhealthconcerns itunes:happynewsandhealthconcerns
# 24
# general:texasorbust itunes:texasorbust
# 25
# general:surgeryandsurprises itunes:surgeryandsurprises
# 26
# general:apizzakatiesheart itunes:apizzakatiesheart
# 27
# general:agreatbatesgetaway itunes:agreatbatesgetaway
# 28
# general:nestingmodemommiesonamission itunes:nestingmodemommiesonamission
# 29
# general:takingcareofbusinessfloridafun itunes:takingcareofbusinessfloridafun
# 30
# general:brandonsbookandkellyjosnewlook itunes:brandonsbookandkellyjosnewlook
# 31
# general:holidaycheerandnewbabykhloeishere itunes:holidaycheerandnewbabykhloeishere
# 32
# general:holidaytraditionsandbabyadditions itunes:holidaytraditionsandbabyadditions
# 33
# general:roaringbatesandpendingduedates itunes:roaringbatesandpendingduedates
# 34
# general:adoubledatesomethingtocelebrate itunes:adoubledatesomethingtocelebrate
# 35
# general:beautyandthebusiness itunes:beautyandthebusiness
# 36
# general:iloveyoutopizzas itunes:iloveyoutopizzas
# 37
# general:theshowmustgoon itunes:theshowmustgoon
# 38
# general:babyboyblessingsbasketballmishaps itunes:babyboyblessingsbasketballmishaps
# 39
# general:shelterinbates itunes:shelterinbates
# 40
#
#
#
#
# general:afirsttimeforeverything amazon:afirsttimeforeverything
# 41
# general:abusybusinessandababybombshell amazon:abusybusinessandababybombshell
# 42
# general:firsthomeandstrictchaperones amazon:firsthomeandstrictchaperones
# 43
# general:happynewsandhealthconcerns amazon:happynewsandhealthconcerns
# 44
# general:texasorbust amazon:texasorbust
# 45
# general:surgeryandsurprises amazon:surgeryandsurprises
# 46
# general:apizzakatiesheart amazon:apizzakatiesheart
# 47
# general:agreatbatesgetaway amazon:agreatbatesgetaway
# 48
# general:nestingmodemommiesonamission amazon:nestingmodemommiesonamission
# 49
# general:takingcareofbusinessfloridafun amazon:takingcareofbusinessfloridafun
# 50
# general:brandonsbookandkellyjosnewlook amazon:brandonsbookandkellyjosnewlook
# 51
# general:holidaycheerandnewbabykhloeishere amazon:holidaycheerandnewbabykhloeishere
# 52
# general:holidaytraditionsandbabyadditions amazon:holidaytraditionsandbabyadditions
# 53
# general:roaringbatesandpendingduedates amazon:roaringbatesandpendingduedates
# 54
# general:adoubledatesomethingtocelebrate amazon:adoubledatesomethingtocelebrate
# 55
# general:beautyandthebusiness amazon:beautyandthebusiness
# 56
# general:iloveyoutopizzas amazon:iloveyoutopizzas
# 57
# general:theshowmustgoon amazon:theshowmustgoon
# 58
# general:babyboyblessingsbasketballmishaps amazon:babyboyblessingsbasketballmishaps
# 59
# general:shelterinbates amazon:shelterinbates
# 60
# y:60
# x:3
# Not Properly Mapped
#
#  Test Case:  22
# Vudu portal is not there.
# len= 13
# general:toathenswithlove apple:toathenswithlove
# 1
# general:findingalovenestinfrance apple:findingalovenestinfrance
# 2
# general:facingtheunknowninukraine apple:facingtheunknowninukraine
# 3
# general:fittingintoosakajapan apple:fittingintoosakajapan
# 4
# general:oldornewinsurreycounty apple:oldornewinsurreycounty
# 5
# general:freezingassetsinlulea apple:freezingassetsinlulea
# 6
# general:blinddateroommates apple:blinddateroommates
# 7
# general:couplebuttsheadsinbruges apple:couplebuttsheadsinbruges
# 8
# general:domestictrackintasmania apple:domestictrackintasmania
# 9
# general:urbanversusruralinnepal apple:urbanversusruralinnepal
# 10
# general:atoddsinpapuanewguinea apple:atoddsinpapuanewguinea
# 11
# general:anendlesssummeronkohsamui apple:anendlesssummeronkohsamui
# 12
# general:californiadreaminginitaly apple:californiadreaminginitaly
# 13
#
#
# general:toathenswithlove google:toathenswithlove
# 14
# general:findingalovenestinfrance google:findingalovenestinfrance
# 15
# general:facingtheunknowninukraine google:facingtheunknowninukraine
# 16
# general:fittingintoosakajapan google:fittingintoosakajapan
# 17
# general:oldornewinsurreycounty google:oldornewinsurreycounty
# 18
# general:freezingassetsinlulea google:freezingassetsinlulea
# 19
# general:blinddateroommates google:blinddateroommates
# 20
# general:couplebuttsheadsinbruges google:couplebuttsheadsinbruges
# 21
# general:domestictrackintasmania google:domestictrackintasmania
# 22
# general:urbanversusruralinnepal google:urbanversusruralinnepal
# 23
# general:atoddsinpapuanewguinea google:atoddsinpapuanewguinea
# 24
# general:anendlesssummeronkohsamui google:anendlesssummeronkohsamui
# 25
# general:californiadreaminginitaly google:californiadreaminginitaly
# 26
#
#
# general:toathenswithlove itunes:toathenswithlove
# 27
# general:findingalovenestinfrance itunes:findingalovenestinfrance
# 28
# general:facingtheunknowninukraine itunes:facingtheunknowninukraine
# 29
# general:fittingintoosakajapan itunes:fittingintoosakajapan
# 30
# general:oldornewinsurreycounty itunes:oldornewinsurreycounty
# 31
# general:freezingassetsinlulea itunes:freezingassetsinlulea
# 32
# general:blinddateroommates itunes:blinddateroommates
# 33
# general:couplebuttsheadsinbruges itunes:couplebuttsheadsinbruges
# 34
# general:domestictrackintasmania itunes:domestictrackintasmania
# 35
# general:urbanversusruralinnepal itunes:urbanversusruralinnepal
# 36
# general:atoddsinpapuanewguinea itunes:atoddsinpapuanewguinea
# 37
# general:anendlesssummeronkohsamui itunes:anendlesssummeronkohsamui
# 38
# general:californiadreaminginitaly itunes:californiadreaminginitaly
# 39
#
#
#
#
# general:toathenswithlove amazon:toathenswithlove
# 40
# general:findingalovenestinfrance amazon:findingalovenestinfrance
# 41
# general:facingtheunknowninukraine amazon:facingtheunknowninukraine
# 42
# general:fittingintoosakajapan amazon:fittingintoosakajapan
# 43
# general:oldornewinsurreycounty amazon:oldornewinsurreycounty
# 44
# general:freezingassetsinlulea amazon:freezingassetsinlulea
# 45
# general:blinddateroommates amazon:blinddateroommates
# 46
# general:couplebuttsheadsinbruges amazon:couplebuttsheadsinbruges
# 47
# general:domestictrackintasmania amazon:domestictrackintasmania
# 48
# general:urbanversusruralinnepal amazon:urbanversusruralinnepal
# 49
# general:atoddsinpapuanewguinea amazon:atoddsinpapuanewguinea
# 50
# general:anendlesssummeronkohsamui amazon:anendlesssummeronkohsamui
# 51
# general:californiadreaminginitaly amazon:californiadreaminginitaly
# 52
# y:52
# x:4
# Not Properly Mapped
#
#  Test Case:  23
# Vudu portal is not there.
# len= 1
# general:dyingtobeyou apple:dyingtobeyou
# 1
#
#
# general:dyingtobeyou google:dyingtobeyou
# 2
#
#
# general:dyingtobeyou itunes:dyingtobeyou
# 3
#
#
#
#
# general:dyingtobeyou amazon:dyingtobeyou
# 4
# y:4
# x:4
# Not Properly Mapped
#
#  Test Case:  24
# Amazon portal is not there.
# len= 17
# general:pilot apple:pilot
# 1
# general:thebigbranhypothesis apple:thebigbranhypothesis
# 2
# general:thefuzzybootscorollary apple:thefuzzybootscorollary
# 3
# general:theluminousfisheffect apple:theluminousfisheffect
# 4
# general:thehamburgerpostulate apple:thehamburgerpostulate
# 5
# general:themiddleearthparadigm apple:themiddleearthparadigm
# 6
# general:thedumplingparadox apple:thedumplingparadox
# 7
# general:thegrasshopperexperiment apple:thegrasshopperexperiment
# 8
# general:thecooperhofstadterpolarization apple:thecooperhofstadterpolarization
# 9
# general:theloobenfelddecay apple:theloobenfelddecay
# 10
# general:thepancakebatteranomaly apple:thepancakebatteranomaly
# 11
# general:thejerusalemduality apple:thejerusalemduality
# 12
# general:thebatjarconjecture apple:thebatjarconjecture
# 13
# general:thenerdvanaannihilation apple:thenerdvanaannihilation
# 14
# general:theshiksaindeterminacy apple:theporkchopindeterminacy
# 14
# general:thepeanutreaction apple:thepeanutreaction
# 15
# general:thetangerinefactor apple:thetangerinefactor
# 16
#
#
# general:pilot google:pilot
# 17
# general:thebigbranhypothesis google:thebigbranhypothesis
# 18
# general:thefuzzybootscorollary google:thefuzzybootscorollary
# 19
# general:theluminousfisheffect google:theluminousfisheffect
# 20
# general:thehamburgerpostulate google:thehamburgerpostulate
# 21
# general:themiddleearthparadigm google:themiddleearthparadigm
# 22
# general:thedumplingparadox google:thedumplingparadox
# 23
# general:thegrasshopperexperiment google:thegrasshopperexperiment
# 24
# general:thecooperhofstadterpolarization google:thecooperhofstadterpolarization
# 25
# general:theloobenfelddecay google:theloobenfelddecay
# 26
# general:thepancakebatteranomaly google:thepancakebatteranomaly
# 27
# general:thejerusalemduality google:thejerusalemduality
# 28
# general:thebatjarconjecture google:thebatjarconjecture
# 29
# general:thenerdvanaannihilation google:thenerdvanaannihilation
# 30
# general:theshiksaindeterminacy google:theshiksaindeterminacy
# 31
# general:thepeanutreaction google:thepeanutreaction
# 32
# general:thetangerinefactor google:thetangerinefactor
# 33
#
#
# general:pilot itunes:pilot
# 34
# general:thebigbranhypothesis itunes:thebigbranhypothesis
# 35
# general:thefuzzybootscorollary itunes:thefuzzybootscorollary
# 36
# general:theluminousfisheffect itunes:theluminousfisheffect
# 37
# general:thehamburgerpostulate itunes:thehamburgerpostulate
# 38
# general:themiddleearthparadigm itunes:themiddleearthparadigm
# 39
# general:thedumplingparadox itunes:thedumplingparadox
# 40
# general:thegrasshopperexperiment itunes:thegrasshopperexperiment
# 41
# general:thecooperhofstadterpolarization itunes:thecooperhofstadterpolarization
# 42
# general:theloobenfelddecay itunes:theloobenfelddecay
# 43
# general:thepancakebatteranomaly itunes:thepancakebatteranomaly
# 44
# general:thejerusalemduality itunes:thejerusalemduality
# 45
# general:thebatjarconjecture itunes:thebatjarconjecture
# 46
# general:thenerdvanaannihilation itunes:thenerdvanaannihilation
# 47
# general:theshiksaindeterminacy itunes:theshiksaindeterminacy
# 48
# general:thepeanutreaction itunes:thepeanutreaction
# 49
# general:thetangerinefactor itunes:thetangerinefactor
# 50
#
#
# general:pilot vudu:thebigbangtheorypilot
# 51
# general:thebigbranhypothesis vudu:thebigbangtheorythebigbranhypothesis
# 52
# general:thefuzzybootscorollary vudu:thebigbangtheorythefuzzybootscorollary
# 53
# general:theluminousfisheffect vudu:thebigbangtheorytheluminousfisheffect
# 54
# general:thehamburgerpostulate vudu:thebigbangtheorythehamburgerpostulate
# 55
# general:themiddleearthparadigm vudu:thebigbangtheorythemiddleearthparadigm
# 56
# general:thedumplingparadox vudu:thebigbangtheorythedumplingparadox
# 57
# general:thegrasshopperexperiment vudu:thebigbangtheorythegrasshopperexperiment
# 58
# general:thecooperhofstadterpolarization vudu:thebigbangtheorythecooperhofstadterpolarization
# 59
# general:theloobenfelddecay vudu:thebigbangtheorytheloobenfelddecay
# 60
# general:thepancakebatteranomaly vudu:thebigbangtheorythepancakebatteranomaly
# 61
# general:thejerusalemduality vudu:thebigbangtheorythejerusalemduality
# 62
# general:thebatjarconjecture vudu:thebigbangtheorythebatjarconjecture
# 63
# general:thenerdvanaannihilation vudu:thebigbangtheorythenerdvanaannihilation
# 64
# general:theshiksaindeterminacy vudu:thebigbangtheorytheshiksaindeterminacy
# 65
# general:thepeanutreaction vudu:thebigbangtheorythepeanutreaction
# 66
# general:thetangerinefactor vudu:thebigbangtheorythetangerinefactor
# 67
#
#
# y:67
# x:4
# Not Properly Mapped
